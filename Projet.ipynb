# %%
#Importation des bibliothèques et fonctions dont on aura besoin
import pandas as pds
import numpy as np
import matplotlib.pyplot as plt
import collections
import seaborn as sns

# %%
df1 = pds.read_csv("hospital_1.csv", delimiter=",") #Chargement du dataset 1
df1
# Out:
#       Account_Num                      Facility Name  \
# 0           10605             SAGE MEMORIAL HOSPITAL
# 1           24250        WOODRIDGE BEHAVIORAL CENTER
# 2           10341           DOUGLAS GARDENS HOSPITAL
# 3           81101  SUNCOAST BEHAVIORAL HEALTH CENTER
# 4           39835           TREASURE VALLEY HOSPITAL
# ...           ...                                ...
# 5334        92281      JEWISH HOSPITAL - SHELBYVILLE
# 5335        65248         DAYTON CHILDREN'S HOSPITAL
# 5336        92377         NORTH TEXAS STATE HOSPITAL
# 5337        71562               GULF BREEZE HOSPITAL
# 5338        51586            I-70 COMMUNITY HOSPITAL
#
#                              Address           City State  ZIP Code  \
# 0          STATE ROUTE 264 SOUTH 191         GANADO    AZ     86505
# 1               600 NORTH 7TH STREET   WEST MEMPHIS    AR     72301
# 2                    5200 NE 2ND AVE          MIAMI    FL     33137
# ...

# %%
df2 = pds.read_csv("hospital_2.csv", delimiter=",") #Chargement du dataset 2
df2
# Out:
#       Provider_Num                                      Provider Name  \
# 0           839987                   SOUTHEAST ALABAMA MEDICAL CENTER
# 1           519118                      MARSHALL MEDICAL CENTER SOUTH
# 2           733073                     ELIZA COFFEE MEMORIAL HOSPITAL
# 3           201752                           MIZELL MEMORIAL HOSPITAL
# 4           678488                                  ST VINCENT'S EAST
# ...            ...                                                ...
# 2692        403227  BAYLOR SCOTT & WHITE MEDICAL CENTER- COLLEGE S...
# 2693        797810                         WALNUT HILL MEDICAL CENTER
# 2694        611900              BAY AREA REGIONAL MEDICAL CENTER, LLC
# 2695        693781                           RESOLUTE HEALTH HOSPITAL
# 2696        322584  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
#
#          Provider Street Address    Provider City Provider State  \
# ...
