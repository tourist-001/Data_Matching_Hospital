# %%
import pandas as pd
import numpy as np

# %%
host1 = pd.read_csv('hospital_1.csv')
host2 = pd.read_csv('hospital_2.csv')
host2
# Out:
#       Provider_Num                                      Provider Name  \
# 0           839987                   SOUTHEAST ALABAMA MEDICAL CENTER
# 1           519118                      MARSHALL MEDICAL CENTER SOUTH
# 2           733073                     ELIZA COFFEE MEMORIAL HOSPITAL
# 3           201752                           MIZELL MEMORIAL HOSPITAL
# 4           678488                                  ST VINCENT'S EAST
# ...            ...                                                ...
# 2692        403227  BAYLOR SCOTT & WHITE MEDICAL CENTER- COLLEGE S...
# 2693        797810                         WALNUT HILL MEDICAL CENTER
# 2694        611900              BAY AREA REGIONAL MEDICAL CENTER, LLC
# 2695        693781                           RESOLUTE HEALTH HOSPITAL
# 2696        322584  BAYLOR SCOTT & WHITE MEDICAL CENTER - MARBLE F...
#
#          Provider Street Address    Provider City Provider State  \
# ...

# %%
final_host = host1.merge(host2, left_on='Facility Name', right_on='Provider Name', how='inner', suffixes=('_left', '_right'))
final_host
# Out:
#       Account_Num                         Facility Name  \
# 0           59519           MARIA PARHAM MEDICAL CENTER
# 1           71617     NEWARK BETH ISRAEL MEDICAL CENTER
# 2           39365                   HOLY CROSS HOSPITAL
# 3           39365                   HOLY CROSS HOSPITAL
# 4           39365                   HOLY CROSS HOSPITAL
# ...           ...                                   ...
# 2734        52595                 SIERRA MEDICAL CENTER
# 2735        18990           FAIRBANKS MEMORIAL HOSPITAL
# 2736        91079  VANDERBILT UNIVERSITY MEDICAL CENTER
# 2737        92281         JEWISH HOSPITAL - SHELBYVILLE
# 2738        71562                  GULF BREEZE HOSPITAL
#
#                         Address         City State  ZIP Code  \
# 0                     PO BOX 59    HENDERSON    NC     27536
# 1                 201 LYONS AVE       NEWARK    NJ      7112
# 2            2701 W 68TH STREET      CHICAGO    IL     60629
# ...
